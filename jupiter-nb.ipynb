# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.034495582224583106), np.float64(0.9987152286742593))

# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.021086019037533384), np.float64(0.9685275914604373))

# %%
# %timeit np.random.randn(10000)
# Out:
# 79.6 μs ± 2.33 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %matplotlib inline

# %%
import numpy as np
import tensorflow as tf

X_train = np.random.randn(500, 10)
y_train = np.random.randint(0, 2, size=(500,))

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(10,)),
    tf.keras.layers.Dense(16, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid"),
])

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
# %%time
model.fit(X_train, y_train, epochs=10)

# %%
# Out:
# UsageError: Environment does not have key: CUDA_VISIBLE_DEVICES

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 7], [1, 4, 2, 9])
plt.title("Inline Plot")
plt.show()

# %% [markdown]
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(8, 4))
# plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
# plt.title("Inline Plot")
# plt.show()

# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.020590538659051114), np.float64(0.9933679793447796))

# %%
from IPython.display import Image, display
display(Image(filename="dsa-patterns-master.png"))

# %%
from IPython.display import Image, display
display(Image(filename="dsa-patterns-master.jpeg"))

# %%
from IPython.display import Image, display
display(Image(filename="dsa-patterns.jpeg"))

# %%
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')
print(physical_devices)
# Out:
# []
